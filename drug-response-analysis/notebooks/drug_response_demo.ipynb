# %% [markdown]
# # Drug Response Demo
# This notebook demonstrates the pipeline on a synthetic drug-response dataset.
#
# It runs a baseline Random Forest and a small TensorFlow model and shows simple evaluation plots.

# %%
# Load the dataset and show a few rows
import pandas as pd
df = pd.read_csv("data/synthetic_drug_response.csv")
df.head()

# %%
# Basic EDA: distribution of response
import matplotlib.pyplot as plt
plt.hist(df["response"], bins=40)
plt.title("Response distribution")
plt.show()

# %%
# Run the pipeline (this will train models and write results to results/demo)
# !python src/pipeline.py --data data/synthetic_drug_response.csv --out_dir results/demo --target response

# %%
# Show metrics
import json
print("Metrics:")
print(open("results/demo/metrics.json").read())
